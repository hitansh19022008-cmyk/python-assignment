# %%
# list
# list is order , muatable, store diiferent dataz types ,allow different data types
# formed using the square brackett
list1 = ["Hitansh","ram","krishna","mahadev"]
print(list1)
# Out:
# ['Hitansh', 'ram', 'krishna', 'mahadev']

# %%
# adding the single element in the list
list1.append("ganpati")
print(list1)
# Out:
# ['Hitansh', 'ram', 'krishna', 'mahadev', 'ganpati']

# %%
# adding the double or more element in the list
list1.extend(["hanuman","mahaveer"])
print(list1)
# Out:
# ['Hitansh', 'ram', 'krishna', 'mahadev', 'ganpati', 'hanuman', 'mahaveer', 'hanuman', 'mahaveer']

# %%
# to replace element in the list
list1.insert(0,"ganpati")
print(list1)
# Out:
# ['ganpati', 'Hitansh', 'ram', 'krishna', 'mahadev', 'ganpati', 'hanuman', 'mahaveer', 'hanuman', 'mahaveer']

# %%
# to countthe no of element of same type in the list
list1.count("ganpati")
print(list1)
# Out:
# ['ganpati', 'Hitansh', 'ram', 'krishna', 'mahadev', 'ganpati', 'hanuman', 'mahaveer', 'hanuman', 'mahaveer']

# %%
a=list1.count("ganapti")
print(a)
# Out:
# 0

# %%
# to give the alphabatical order of the element in the list
list1.sort()
print(list1)
# Out:
# ['Hitansh', 'ganpati', 'ganpati', 'hanuman', 'hanuman', 'krishna', 'mahadev', 'mahaveer', 'mahaveer', 'ram']

# %%
# to remove the element in the list fronm the last
list1.pop()
print(list1)
# Out:
# ['Hitansh', 'ganpati', 'ganpati', 'hanuman', 'hanuman', 'krishna', 'mahadev', 'mahaveer', 'mahaveer']

# %%
#to remove the elemnt of specific index
list1.pop(2)
print(list1)
# Out:
# ['Hitansh', 'ganpati', 'hanuman', 'hanuman', 'krishna', 'mahadev', 'mahaveer', 'mahaveer']

# %%
list1.remove("hanuman")
print(list1)
# Out:
# ['Hitansh', 'ganpati', 'hanuman', 'krishna', 'mahadev', 'mahaveer', 'mahaveer']

# %%
print(list1[0:6:1])
# Out:
# ['Hitansh', 'ganpati', 'hanuman', 'krishna', 'mahadev', 'mahaveer']

# %%
print(list1[ : :-1])
# Out:
# ['mahaveer', 'mahaveer', 'mahadev', 'krishna', 'hanuman', 'ganpati', 'Hitansh']

# %%
# tuples
# tuples is same like the list but they are immuable
# ordered , immutable, store data of same type or diiferent type 
# they are formed by thr using parentheses backett ()
tuple1 = (" ganpati","ram","krishna","mahadev")
print(tuple1)
# Out:
# (' ganpati', 'ram', 'krishna', 'mahadev')

# %%
# to access the element in the tuple 
print(tuple1[2])
# Out:
# krishna

# %%
# to check the length of the tuple
print(len(tuple1))
# Out:
# 4

# %%
# to add element in the tuple 
# first to vconvert the tuple in the list
# then add element in the list
# again convet the list into the tuple and hence element is added to tuple
a = ("ganapti","krishna","mahadev")
print(a)
b=list(a)
print(b)
b.extend(["ram","mahaveer"])
c=tuple(b)
print(c)
# Out:
# ('ganapti', 'krishna', 'mahadev')
# ['ganapti', 'krishna', 'mahadev']
# ('ganapti', 'krishna', 'mahadev', 'ram', 'mahaveer')

# %%
# to remove element in the tuple
print(a)
d = list(a)
print(d)
d.remove("mahadev")
e=tuple(d)
print(e)
# Out:
# ('ganapti', 'krishna', 'mahadev')
# ['ganapti', 'krishna', 'mahadev']
# ('ganapti', 'krishna')

# %%
# slicing of the element in the tuple
print(tuple1[0:1:1])
# Out:
# (' ganpati',)

# %%
print(tuple1[0:2:1])
# Out:
# (' ganpati', 'ram')

# %%
print(tuple1[0:3:1])
# Out:
# (' ganpati', 'ram', 'krishna')

# %%
print(tuple1[0:3:2])
# Out:
# (' ganpati', 'krishna')

# %%
# dictionarry
# dictionaey is the collection used to store data 
# oredered , mutable, duplicate is allowed
# formed using the curely brackets 
student = {"name":"hitansh","age":18,"prn":1272260661,"percentage":89}
print(student)
# Out:
# {'name': 'hitansh', 'age': 18, 'prn': 1272260661, 'percentage': 89}

# %%
# accesing the element in the dictionary
print(student["name"])
# Out:
# hitansh

# %%
print(student["age"])
# Out:
# 18

# %%
# updating the value in the dictionary 
student.update({"percentage":90})
print(student)
# Out:
# {'name': 'hitansh', 'age': 18, 'prn': 1272260661, 'percentage': 90}

# %%
# deleting the element in the dictionary
student.pop("prn")
print(student)
# Out:
# {'name': 'hitansh', 'age': 18, 'percentage': 90}

# %%
# to see all the key in the dictinary
student.keys()
print(student)
# Out:
# {'name': 'hitansh', 'age': 18, 'percentage': 90}

# %%
# to see all items in the dictionary 
student.items()
print(student)
# Out:
# {'name': 'hitansh', 'age': 18, 'percentage': 90}

# %%
# to see all the values in the dictionary 
student.values()
print(student)
# Out:
# {'name': 'hitansh', 'age': 18, 'percentage': 90}

# %%
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'percentage'])

# %%
print(student.values())
# Out:
# dict_values(['hitansh', 18, 90])
