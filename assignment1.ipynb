# %%
# list operations
list1 = ["aarav","bhavana","chetan"]
print(list1)
# Out:
# ['aarav', 'bhavana', 'chetan']

# %%
list1.append("divya")
print(list1)
# Out:
# ['aarav', 'bhavana', 'chetan', 'divya']

# %%
list1.insert(1,"bhavesh")
print(list1)
# Out:
# ['aarav', 'bhavesh', 'bhavana', 'chetan', 'divya']

# %%
list1.remove("bhavana")
print(list1)
# Out:
# ['aarav', 'bhavesh', 'chetan', 'divya']

# %%
list1.pop(1)
print(list1)
# Out:
# ['aarav', 'chetan', 'divya']

# %%
list1.sort()
print(list1)
# Out:
# ['aarav', 'chetan', 'divya']

# %%
list1.extend(["akash","aryaman"])
print(list1)
# Out:
# ['aarav', 'chetan', 'divya', 'akash', 'aryaman']

# %%
# tuple operations
tuple1 =  ("aarav","bhavana","chetan")
print(tuple1)
# Out:
# ('aarav', 'bhavana', 'chetan')

# %%
# length of the tuple
print(len(tuple1))
# Out:
# 3

# %%
# adding element
tuple1 = ("aarav","bhavana","chetan")
x = ("divya",2)
tuple1 += x
print("add tuple function:",tuple1)
# Out:
# add tuple function: ('aarav', 'bhavana', 'chetan', 'divya', 2)

# %%
# multiplying the tuple 
tuple1 = ("aarav","chetan","bhavana")
tuple2 = tuple1*3
print(tuple2)
# Out:
# ('aarav', 'chetan', 'bhavana', 'aarav', 'chetan', 'bhavana', 'aarav', 'chetan', 'bhavana')

# %%
t = ("aarav","chetan","bhavana")
print(t)
a = list(t)
print(a)
a.append("divya")
t=tuple(a)
print(a)
# Out:
# ('aarav', 'chetan', 'bhavana')
# ['aarav', 'chetan', 'bhavana']
# ['aarav', 'chetan', 'bhavana', 'divya']

# %%
# dictionary operations
students = {101:"aarav",102:"bhavana",103:"chetan"}
print(students)
# Out:
# {101: 'aarav', 102: 'bhavana', 103: 'chetan'}

# %%
# accessing the value
print(students[102])
# Out:
# bhavana

# %%
# adding the element 
students[104]="divya"
students
# Out:
# {101: 'aarav', 102: 'bhavana', 103: 'chetan', 104: 'divya'}

# %%
print(students.keys())
# Out:
# dict_keys([101, 102, 103, 104])

# %%
print(students.values())
# Out:
# dict_values(['aarav', 'bhavana', 'chetan', 'divya'])

# %%
print(students.items())
# Out:
# dict_items([(101, 'aarav'), (102, 'bhavana'), (103, 'chetan'), (104, 'divya')])

# %%
students.pop(101)
print(students)
# Out:
# {102: 'bhavana', 103: 'chetan', 104: 'divya'}
